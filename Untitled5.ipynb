# %% [markdown]
# <a href="https://colab.research.google.com/github/SksuriyaPrakash/1DL/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hii")
# Out:
# hii
